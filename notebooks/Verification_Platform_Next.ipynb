# %% [markdown]
# # Verification Platform Next
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/iguchi-lab/Verification-Platform-Next/blob/main/notebooks/Verification_Platform_Next.ipynb)
#
# このノートブックは、共通スキーマから生成される Gradio アプリを Colab で起動するための薄いランチャーです。入力定義や計算ロジックはリポジトリ内のパッケージにあります。
#
# ## 使い方
#
# 1. Colabのメニューで **ランタイム > すべてのセルを実行** を選びます。
# 2. 最初のコードセルがリポジトリの取得・更新とアプリのインストールを行います。
# 3. 最後のコードセルに `Running on public URL: https://....gradio.live` と表示されるまで待ちます。
# 4. 表示された **`https://....gradio.live` のリンク** をクリックしてアプリを開きます。`0.0.0.0` や `127.0.0.1` のリンクはColabの外からは開けません。
# 5. アプリを使っている間は、最後のコードセルを実行したままにしてください。
#
# 公開リンクは一時的なものです。再起動するとURLが変わるため、新しく表示されたリンクを開いてください。

# %%
# %cd /content
![ -d Verification-Platform-Next/.git ] || git clone --depth 1 https://github.com/iguchi-lab/Verification-Platform-Next.git Verification-Platform-Next
# !git -C Verification-Platform-Next pull --ff-only
# %cd /content/Verification-Platform-Next
# %pip install -e apps/gradio

# %%
# %env GRADIO_SHARE=1
# %env GRADIO_SERVER_NAME=0.0.0.0
# %env GRADIO_DEBUG=1
# %env GRADIO_STATUS_UPDATE_RATE=1
# !python -c "import gradio; print('Gradio', gradio.__version__)"
# !verification-platform
